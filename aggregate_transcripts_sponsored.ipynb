# %% [markdown]
# ## Aggregating Transcripts from Sponsored Videos

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
PATH = "E:/Facebook/transcripts/sponsored/"

# %% [markdown]
# Functions to read transcript files.

# %%
# load the transcripts
def read_transcript(file, encoding = 'utf-8'):
    with open(file, 'r', encoding=encoding) as f:
        transcript = f.read()
        return transcript

# %%
# create a dictionary of video_id and transcript
transcript_dict = {}
print("Creating transcript dictionary")
for root, dirs, files in os.walk(PATH):
    for file in files:
        video_id = file.split(".")[0]
        try:
            transcript_dict[video_id] = read_transcript(os.path.join(root, file))
        except UnicodeDecodeError:
            transcript_dict[video_id] = read_transcript(os.path.join(root, file), encoding='ISO-8859-1')
# Out:
# Creating transcript dictionary

# %%
# create a dataframe from the dictionary
df = pd.DataFrame(transcript_dict.items(), columns=["video_id", "transcript"])
df['video_id'] = df['video_id'].astype(np.int64)
df['length'] = df['transcript'].apply(lambda x: len(x.split()))
# replacing transcripts with length less than 3 words with None
df.loc[df['length'] < 3, 'transcript'] = None
print(df.shape)
print(df.head())
# Out:
# (15013, 3)
#            video_id                                         transcript  length
# 0  1001647963223889                                               None       0
# 1  1001709553198849                                               None       0
# 2  1001753429945245                                               None       1
# 3  1001834046625140  it is now time for my favorite segment of the ...      71
# 4  1002158923207565  November 26th 1986 at 12:00 got out so fast it...      52

# %%
# source data
data = pd.read_csv(r"C:\Users\doosti\OneDrive - Chapman University\Research\Research Projects\Facebook\Tubular\revision_2024\pooled_us_jul2024.csv")
data['video_id'] = data['video_id'].astype(np.int64) # convert video_id to int64
print(data.shape)
# Out:
# (220033, 153)

# %% [markdown]
# Note: To check the mismatch between video ids from source and current data frame, refer to `aggregate_transcripts_sponsored.py` for more details.

# %%
# merge the two dataframes
data['transcript'] = data.merge(df, left_on='new_id', right_on='video_id', how='left').transcript
sponsored = data[data['transcript'].notnull()][['video_id','new_id','creator_name','sponsor_name','transcript']]

# %%
# functions to infer about the transcript
def is_in_text(terms, text):
    if ' '.join(terms).lower() in text.lower():
        return True
    for term in terms:
        if term.lower() in ['the','a','an','of','and','or','in','on','at','to','for','with','by','from','as','is']:
            continue
        if term.lower() in text.lower().split():
            return True
    return False

def term_in_text(terms, text):
    found = []
    if ' '.join(terms).lower() in text.lower():
        return terms
    for term in terms:
        if term.lower() in ['the','a','an','of','and','or','in','on','at','to','for','with','by','from','as','is']:
            continue
        if term.lower() in text.lower().split():
            found.append(term)
    return found

def sponsored_by(text):
    if 'sponsored' in text.lower().split():
        return True
    elif 'brought to you by' in text.lower():
        return True
    return False

# function to show 20 rows of a data frame at a time every time by pressing enter
def display(df):
    for i in range(0, len(df), 20):
        print(df[i:i+20])
        input("Press Enter to continue...")

# %%
# preparing the sponsored data with transcripts
sponsored['terms'] = sponsored.sponsor_name.apply(lambda x: x.split())
sponsored['is_in_text'] = sponsored.apply(lambda x: is_in_text(x.terms, x.transcript), axis=1)
print(f"Number of sponsored videos including sponsor name: {sponsored['is_in_text'].sum()}")
sponsored['found_terms'] = sponsored.apply(lambda x: term_in_text(x.terms, x.transcript), axis=1)
sponsored['sponsored_by'] = sponsored.transcript.apply(sponsored_by)
print(f"Number of sponsored videos including sponsored by: {sponsored['sponsored_by'].sum()}")
# Out:
# Number of sponsored videos including sponsor name: 1631
# Number of sponsored videos including sponsored by: 243

# %%
temp = sponsored[sponsored.is_in_text==True][['sponsor_name','found_terms','transcript']]
temp['found'] = temp.found_terms.apply(lambda x: ' '.join(x))

found = ["Movie","One","Me", "Washington", "Investments", "Be", "Golf", "Park","Coffee","New"]
# New is mixed
# Out:
# Justice League Movie ---- Movie
# Black Adam is an awesome character he's one of my favorite characters in the DC Comics Yoruba to me for me I like characters that are really cool and they think highly of themselves you may have too much but I have the wisdom of God they don't care what anyone says they just do what they please stop what's really interesting oriented where you can throw lightning down he has a whole bunch of different moves that make you scared to approach him his best one is actually is super move I mean it looks like you're in a movie knock knock you into a pyramid and then he calls down lightning which is awesome
#
#
#
# Before I Fall Movie ---- Movie
# so in five words or less Tell me about the movie I'm just kidding OK Google 18
#
#
#
# Capital One ---- One
# a little Bakery in north Texas is beloved for its black forest cake but this isn't the chocolate cherry layer cake you're probably thinking of and angelically Light Affair of crisp Airy almond meringue layered with whipped cream and a shower of chocolate shavings Swiss pastry shop in Fort Worth has been serving its own take on the black forest cake for more than 40 years the bakery actually refers to it as an uncake and after tasting it it's not hard to see why the Heavenly combination of crunchy meringue and fluffy whipped cream means it's super light and not too sweet and as a bonus it's also gluten-free it's a recipe that owner Hans Peter's father brought with him when he came to America from Switzerland in the 60s we are traditional holiday before Christmas and someone told us that we had absolutely ruined their holiday because they couldn't get a cake despite making one of Fort Worth favorite Millersville passion is actually beef Swiss pastry shop might be the only Bakery that's also equipped with a smoker in addition to gigantic Burgers more also serves his own twist on The Cheesesteak a whole rib roast is smoked over pecan wood then sliced and covered with queso blanco and caramelized onions dad's dream was in 1972 he opened his own Bakery which is the Swiss pastry shop we fought a lot I had new fangled ideas about new products he just wanted to sell his black forest cake we get email after email and Facebook post all the time telling us how much that cake means to everyone's family and how they just they really can't have a holiday without it
#
#
#
# Capital One ---- One
# my name is Scott Conant and we are at Fusco restaurant nobody moves to New York for the lifestyle right you're here because you want to get ahead because you want to excel you want to exceed you want to be the best that you can be and its most raw State that's why I love New York City I'm Scott Conan and these are a few of my favorite places in New York time is just an awesome Falafel and I know not the the shuffle really one of the things that I love is just her respect towards product and towards the craft it's just a happy place right by happy people you know perfect ABC song has the broadest culinary vocabulary I think that's just something about that place that I love it's my go-to spot ABC Cocina really kind of just that comforting spot for me I actually helped conceptualize years ago and I'll just sit at the bar and order a Panino and have a glass of wine and the food is always really good they execute really well the barrel agent Negroni at Buffalo is one of my favorite things all so it's just they let it sit in a barrel for at least 30 days and I like to think that it's just Smooths out the edges
#
#
#
# Kiss Him, Not Me ---- Me
#  call me in the face
#
#
#
# NBC Sports Washington ---- Washington
# mark them down at 6:04 the 1st in Washington has scored first now in 6 Straight games and this is a team that starts well Joe and they started well because they're attempting shots
# App                   1
# Dickies               1
# Fitness               1
# Line                  1
# Fortnite              1
# Market                1
# ACME                  1
# Panini                1
# MassMutual            1
# BlackJack             1
# MANNA                 1
# Cheesecake            1
# Mopar                 1
# Netflix               1
# Hollywood             1
# Lowe's                1
# Resort                1
# TuneCore              1
# Publix                1
# Kay                   1
# Her                   1
# Meijer                1
# Kohl's                1
# Beautiful             1
# Ochsner               1
# Hulu                  1
# Honeywell             1
# Pepcid                1
# Food                  1
# ROMWOD                1
# Ram                   1
# FS1                   1
# Gap                   1
# Jesus                 1
# Zwift                 1
# Clarks                1
# Eggology              1
# Stage                 1
# Texas                 1
# Hyundai               1
# Theater               1
# NBA                   1
# Battlefield           1
# My                    1
# Boston                1
# Allstate              1
# Hi-Chew               1
# Geographic            1
# Baywatch              1
# Caribbean             1
# Let's                 1
# Slugger               1
# Hooters               1
# Aveda                 1
# MedStar               1
# Seinfeld              1
# Squarespace           1
# Piedmont              1
# Fifth                 1
# Browning              1
# FIFA                  1
# Denver                1
# End                   1
# HBO                   1
# LG                    1
# Challenge             1
# USA                   1
# Buick                 1
# Get                   1
# More                  1
# Coffee                1
# Company               1
# Flonase               1
# Hospital              1
# BISSELL               1
# Marshall              1
# ModCloth              1
# Medtronic             1
# National              1
# Buy                   1
# KeyBank               1
# Kate                  1
# MLB                   1
# Furniture             1
# CDW                   1
# NovaLash              1
# Bamboobies            1
# Dinner                1
# Christmas             1
# Passengers            1
# UFC                   1
# Run                   1
# Icon                  1
# Hennessy              1
# Cleveland             1
# Naturals              1
# Echo                  1
# Pennzoil              1
# Barrel                1
# FedEx                 1
# STAINMASTER           1
# Smithfield            1
# Super                 1
# Postmates             1
# Fire                  1
# Alcatel               1
# GlobeIn               1
# OxiClean              1
# Muddy                 1
# News                  1
# Date                  1
# Me                    1
# Team                  1
# Callaway              1
# Velcro                1
# Shearwater            1
# PenFed                1
# GUESS                 1
# Fittest               1
# Dale                  1
# Safeway               1
# Nasdaq                1
# Victorinox            1
# Name: found, dtype: int64

# %%
check = ["Date","News","Fire","Team","Super","Icon","Run","Dinner","Kate","Buy","Company","Get","USA","End","Denver","Let's","My","Theater","Stage","Food","Her","Go","Purpose","Arts","Cotton","Today","Holloween","Out","Natural","Are","One","Health","Jack","Happy","Sports","Spice","baby","Old","Nutrition","Center","Muscle","Show"]

# %%
for term in check:
    print(f"Term: ---{term}---")
    for i, row in temp[temp.found==term].iterrows():
        print(f"Sponsor: {row.sponsor_name}")
        for j, token in enumerate(row.transcript.split()):
            if token.lower() == term.lower():
                print('TEXT:',' '.join(row.transcript.split()[j-5:j+5]))
                #break
    print("\n")
# Out:
# Term: ---Date---
# Sponsor: Hot Date
# TEXT: fine time on our regular date this is a two-person
#
#
# Term: ---News---
# Sponsor: FOX10 News
# TEXT:
# TEXT: in another vehicle Fox 10 news reporter Rebecca hager's Live
# TEXT: coming up on Fox 10 News at 9:00 tonight you'll
# TEXT: live from I-65 Fox 10 News
#
#
# Term: ---Fire---
# Sponsor: Kidde Fire Safety
# TEXT: to try and fight a fire or to try and
# TEXT: more likely to start a fire especially while cooking part
# TEXT: if your house catches on fire get out and stay
#
#
# Term: ---Team---
# Sponsor: Team Red, White & Blue
# TEXT: into civilian life the mission team are to enrich the
#
#
# Term: ---Super---
# Sponsor: Live Super Deluxe
# TEXT: favorite Nintendo game Mario Kart Super Mario Brothers California play
#
#
# Term: ---Icon---
# Sponsor: Icon
# TEXT: help you out we made icon underwear so women can
#
#
# Term: ---Run---
# Sponsor: Nike+ Run Club
# TEXT: that my flip during your run these perforations in the
#
#
# Term: ---Dinner---
# Sponsor: Beatriz at Dinner
# TEXT: is not working Beatrice at dinner rated R
#
#
# Term: ---Kate---
# Sponsor: Kate Somerville Skincare
# TEXT: wearing makeup and because of Kate I'm not wearing makeup
#
#
# Term: ---Buy---
# Sponsor: Best Buy
# TEXT: sell the Cavaliers and then buy his hometown team Gilbert
#
#
# Term: ---Company---
# Sponsor: Blue Moon Brewing Company
# TEXT: all can enjoy each other's company and get along every
#
#
# Term: ---Get---
# Sponsor: Get America Covered
# TEXT: the ACA most people can get plans that cost less
# TEXT: TV go to healthcare.gov and get insured now
#
#
# Term: ---USA---
# Sponsor: BMW USA
# TEXT: the young star from the USA Michael Branigan plenty of
#
#
# Term: ---End---
# Sponsor: Lands' End
# TEXT: of The Weather Channel Lands End first off winter weather
#
#
# Term: ---Denver---
# Sponsor: Denver Center for the Performing Arts
# TEXT:
#
#
# Term: ---Let's---
# Sponsor: CFP Let's Make a Plan
# TEXT: like this to you now let's say you are a
# TEXT: want to come over here let's tear it up and
#
#
# Term: ---My---
# Sponsor: My Black is Beautiful
# TEXT:
# TEXT: without working hard for it my name is Skai Jackson
#
#
# Term: ---Theater---
# Sponsor: Dallas Theater Center
# TEXT: of being done in the theater so it's nice that
#
#
# Term: ---Stage---
# Sponsor: Honda Stage
# TEXT: a cheat code on the stage with them that was
#
#
# Term: ---Food---
# Sponsor: Save the Food
# TEXT:
# TEXT: a third of the world's food never gets eaten in
# TEXT: so much closer to the food and you start to
#
#
# Term: ---Her---
# Sponsor: NLA for Her
# TEXT:
#
#
# Term: ---Go---
# Sponsor: Go RVing
# TEXT: make it pretty easy to go explore what's a different
#
#
# Term: ---Purpose---
# Sponsor: A Dog's Purpose
# TEXT: you too you give me purpose
#
#
# Term: ---Arts---
# Sponsor: AT&T Performing Arts Center
# TEXT: House WFAA is elevating the Arts
#
#
# Term: ---Cotton---
# Sponsor: Cotton
# TEXT: shaking her shirt especially a cotton t-shirt is pretty much
#
#
# Term: ---Today---
# Sponsor: Walmart Today
# TEXT: for Trace back to consumers today are very far removed
#
#
# Term: ---Holloween---
#
#
# Term: ---Out---
# Sponsor: Lights Out
# TEXT: light if your electricity goes out search for a potato
# TEXT: strand candles if you run out of candles a box
#
#
# Term: ---Natural---
# Sponsor: Beyond Natural Pet Food
# TEXT: going to love me on natural biscuits
#
#
# Term: ---Are---
# Sponsor: We Are The Mighty
# TEXT: he thought that he soldiers are nearly his parents and
#
#
# Term: ---One---
# Sponsor: Capital One
# TEXT: get a cake despite making one of Fort Worth favorite
# Sponsor: Capital One
# TEXT: not the the shuffle really one of the things that
# TEXT: agent Negroni at Buffalo is one of my favorite things
#
#
# Term: ---Health---
# Sponsor: Henry Ford Health System
# TEXT: today with the District 5 health fair for get fit
# Sponsor: Henry Ford Health System
# TEXT: your emotional well-being improve your health and restore your memory
#
#
# Term: ---Jack---
# Sponsor: Jack in the Box
# TEXT: a folder of images reveals Jack was trying his hand
# TEXT: painting trying to be fancy Jack wow I am shocked
# TEXT: I am shocked shocked that Jack would paint something from
# Sponsor: Jack in the Box
# TEXT: hacked personal email a screenplay Jack is writing has surfaced
#
#
# Term: ---Happy---
# Sponsor: Happy Death Day
# TEXT: birthday
# Sponsor: Happy Death Day
# TEXT:
#
#
# Term: ---Sports---
# Sponsor: Yahoo Sports
# TEXT: were playing soccer and another Sports and basketball but my
# Sponsor: BPI Sports
# TEXT: normal weight the muscle Roller Sports
#
#
# Term: ---Spice---
# Sponsor: McCormick Spice
# TEXT:
# Sponsor: McCormick Spice
# TEXT: the wrapped pineapple with your spice mixture broil until Brown
#
#
# Term: ---baby---
# Sponsor: JOHNSON'S baby
# TEXT: anyone who's ever thrown a baby shower for their bestie
# TEXT: tricks to make your next baby shower easy affordable and
# TEXT: with Mama actually use my baby arrives encourage all your
# Sponsor: JOHNSON'S baby
# TEXT: anyone who's ever thrown a baby shower for their bestie
# TEXT: tricks to make your next baby shower easy affordable and
# TEXT: gifts Mama actually use once baby arrives encourage all your
#
#
# Term: ---Old---
# Sponsor: Cracker Barrel Old Country Store
# TEXT: you would feel from some old rugged cowboy I think
# Sponsor: Cracker Barrel Old Country Store
# TEXT: you would feel from some old rugged cowboy I think
# Sponsor: Old Spice
# TEXT: 2008 it's almost 9 years old and still has no
#
#
# Term: ---Nutrition---
# Sponsor: Optimum Nutrition
# TEXT: brought Health and Fitness Sports Nutrition has been able to
# TEXT: make the most effective Subway nutrition and bodybuilding.com nutrition celebrating
# TEXT: effective Subway nutrition and bodybuilding.com nutrition celebrating 30 years of
# Sponsor: Optimum Nutrition
# TEXT: Patron sponsored athlete with often nutrition at fitness model this
# Sponsor: Optimum Nutrition
# TEXT: brought to you by Austin nutrition weekly challenges and plenty
#
#
# Term: ---Center---
# Sponsor: Straz Center for the Performing Arts
# TEXT: Seasons coming to the stress Center June 1st through 5th
# Sponsor: Straz Center for the Performing Arts
# TEXT: Paris coming to the stress Center December 20th through 25th
# TEXT: 20th through 25th visit Stress Center Dot
# Sponsor: Straz Center for the Performing Arts
# TEXT:
#
#
# Term: ---Muscle---
# Sponsor: Kaged Muscle Supplements
# TEXT: news about the new cage muscle casing that has come
# Sponsor: Kaged Muscle Supplements
# TEXT: with confidence you will build muscle you will burn fat
# Sponsor: Kaged Muscle Supplements
# TEXT: have you seen me build muscle burn fat and now
# TEXT: this program is to build muscle complete an iron distance
# Sponsor: Muscle Milk
# TEXT: change the perceived image of muscle women from docile and
# Sponsor: Kaged Muscle Supplements
# TEXT: are beats up and my muscle groups are so it
#
#
# Term: ---Show---
# Sponsor: MLB The Show
# TEXT:
# TEXT: show the Galaxy loves the show because it's epic Stars
# TEXT: it's epic Stars love the show because they're in it
# TEXT: they're in it loves the show because it's always evolving
# TEXT: evolving conspiracy theories love to show because it's not what
# Sponsor: MLB The Show
# TEXT: me results
# TEXT: results
# Sponsor: MLB The Show
# TEXT:
# TEXT:
# Sponsor: MLB The Show
# TEXT: Aaron Sanchez welcome to the show man do you ever
# Sponsor: MLB The Show
# TEXT: man you actually play the show all the time correct

# %%
clear = ["Icon", "Run", "Dinner", "Kate", "Get", "USA", "End", "Stage", "Food", "Go", "Purpose", "Cotton", "Out", "Natural", "Happy", "Spice", "Center", "Muscle"]
not_sure = ['Health', "Jack", "baby"]
# flagging terms based on check and found minus clear and not_sure
remove_terms = []
for term in found+check:
    if term in clear:
        remove_terms.append(term)
    elif term in not_sure:
        remove_terms.append(term)
print(f"Number of terms to remove: {len(remove_terms)}")
# Out:
# Number of terms to remove: 21

# %%
def remove(text, terms):
    if len(text) == 0:
        return text
    if text[0] in terms:
        return []
    return text
# remove terms from the list
print(sponsored.found_terms.value_counts().iloc[:4])
print(sponsored.found_terms.apply(remove, terms=remove_terms).value_counts().iloc[:4])

sponsored['found_terms'] = sponsored.found_terms.apply(remove, terms=remove_terms)

mask = sponsored.found_terms.apply(lambda x: len(x)) == 0
sponsored.loc[mask, 'is_in_text'] = False
print(sponsored.is_in_text.value_counts())
# Out:
# []                 4593
# [Dr, Pepper]         66
# [Edward, Jones]      57
# [84, Lumber]         32
# Name: found_terms, dtype: int64
# []                 4593
# [Dr, Pepper]         66
# [Edward, Jones]      57
# [84, Lumber]         32
# Name: found_terms, dtype: int64
# False    4593
# True     1593
# Name: is_in_text, dtype: int64

# %%
# if they use patreon
patreon = sponsored[sponsored.transcript.str.contains('patreon', case=False)]
patreon.shape
# Out:
# (0, 9)

# %%
# save sponsored
sponsored.to_csv(r"C:\Users\doosti\OneDrive - Chapman University\Research\Research Projects\Facebook\Tubular\revision_2024\sponsored.csv", index=False)

# %%
# load sponsored
sponsored = pd.read_csv(r"C:\Users\doosti\OneDrive - Chapman University\Research\Research Projects\Facebook\Tubular\revision_2024\sponsored.csv")

# %%
def search_term(term,docs):
    for i,trans in enumerate(docs):
        tokens = trans.split()
        for j, token in enumerate(tokens):
            if term in token.lower():
                start = j - 10
                end = j + 10
                if start < 0:
                    start = 0
                if end > len(tokens):
                    end = len(tokens)
                print(f'Found on documnet {i}:',' '.join(trans.split()[start:end]))
                print("\n")

search_term("iphone",sponsored.transcript)
# Out:
# Found on documnet 293: on the Android store or on the App Store on iPhones remember you can also go to chatsports.com tickets to
#
#
# Found on documnet 317: matchup they haven't shown that they can dominate of my iPhone go to Facebook live and give that like button
#
#
# Found on documnet 317: I'm giving it a heart baby I'm pulling out my iPhone going to Facebook live chat sports the leader in
#
#
# Found on documnet 317: one and I'm giving the heart I'm pulling out my iPhone for Clemson I think they're going to win this
#
#
# Found on documnet 317: one and I'm giving the heart I'm pulling on my iPhone for Clemson I think they're going to win this
#
#
# Found on documnet 317: one and I'm giving the heart I'm pulling out my iPhone I'm hitting that heart button for Clemson I think
#
#
# Found on documnet 317: the big one and I'm giving the heart on my iPhone for Clemson I think they're going to win this
#
#
# Found on documnet 317: one and I'm giving the heart I'm pulling out my iPhone for Clemson I think they're going to win this
#
#
# Found on documnet 318: some other people that pay $250 for the tickets for iPhone 2017 Heisman Trophy winner babying 75 years old right
#
#
# Found on documnet 319: here at chat sports it's almost like 90% volume for iPhone and Android so we're going to go to the
#
#
# Found on documnet 1053: nothing to make us that's interesting except like slap some iPhone into another like $400 on your phone it's like
#
#
# Found on documnet 1058: the thing that I do every week called stronger together iPhone and it has literally everything sounds like a dumb
#
#
# Found on documnet 1058: it's literally an Android phone on the back of your iPhone so well the cool things that they do is
#
#
# Found on documnet 1058: is this Android phone that's on the back of your iPhone for like 15 minutes what's stronger together that's my
#
#
# Found on documnet 1816: one goal of his own Telemundo had the best call iPhone
#
#
# Found on documnet 1840: have people that can not just be lost in their iPhone but instead get truly get completely immersed is that
#
#
# Found on documnet 3023: back to 2009 you were probably downloading apps on your iPhone 3GS and watching a strange commercial from Domino's where
#
#
# Found on documnet 3385: there's something else new on the iPhone if you updated to iOS 10 you can get
#
#
# Found on documnet 3567: but Tesla reminds me of the early days of the iPhone when Apple had a clearly Superior and revolutionary product
#
#
# Found on documnet 3968: recently hit a new high after the announcement of the iPhone 8 event what does Apple need to do for
#
#
# Found on documnet 3968: in terms of how they're gaining market share the new iPhone that is expected to be introduced I think within
#
#
# Found on documnet 3968: clear that a major growth driver Beyond just the new iPhone is going to be the services business which I
#
#
# Found on documnet 3968: going to be really interesting to see what the new iPhone consists of and a lot of news has been
#
#
# Found on documnet 4002: if it seems like everybody's been waiting for this new iPhone it might be because they have Matt Drucker the
#
#
# Found on documnet 4538: many people expected the reveal of the iPhone x to trigger an upgrade super cycle and lead
#
#
# Found on documnet 4538: and lead to a great increase in the number of iPhone sold in 2018 one of the reasons that people
#
#
# Found on documnet 4538: of the reasons that people expected this was because the iPhone x was going to be one of the first
#
#
# Found on documnet 4538: be one of the first new design reveals since the iPhone 6 UBS is a little bit differently results from
#
#
# Found on documnet 4538: from a year ago for people planning to upgrade their iPhones and they're also showing that the average age of
#
#
# Found on documnet 4538: in the number of people that are buying the new iPhone x UPS Store that Apple was presenting and that
#
#
# Found on documnet 4538: months they just don't expect to see a pickup and iPhone sales that many others had expected according to ubs's
#
#
# Found on documnet 4538: to ubs's Stephen malanowicz the stock narrative should shift from iPhone Cycles to iPhone annuity how does Apple monetize the
#
#
# Found on documnet 4538: malanowicz the stock narrative should shift from iPhone Cycles to iPhone annuity how does Apple monetize the installed base through
